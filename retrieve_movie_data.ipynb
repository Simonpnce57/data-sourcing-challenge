# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
load_dotenv("thekeys.env")
# Out:
# True

# %% [markdown]
# ### Access the New York Times API

# %%
# Set environment variables from the .env in the local environment
load_dotenv("/Users/simonponce/Desktop/AI_Bootcamp/M6_Starter_code/data-sourcing-challenge/thekeys.env")

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")
nyt_api_secret = os.getenv("NYT_API_SECRET")

# %%
full_url = f"{url}{headline}&page={10}&api-key={nyt_api_key}"

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

#url_keyed = f"{url}love{headline}&api-key={nyt_api_key}"

#url_query = f'{url}api-key={nyt_api_key}&api-secret={nyt_api_secret}"


# Filter for movie reviews with "love" in the headline
headline = "love"
# section_name should be "Movies"
section_name = "movies"

# type_of_material should be "Review"
#filter_query = "section_name:('Movies') AND type_of_material:('Review') AND headline:('love')"
type_of_material = "review"
# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

 

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
#query_url = f"{url}{headline}&api-key={nyt_api_key}&api-secret={nyt_api_secret}&fq={filter_query}&type_of_material={type_of_material}&sort={sort}&begin_date={begin_date}&end_date={end_date}&fl={field_list}"

#query_url

#url_query = f"{url}{headline}&api-key={nyt_api_key}&api-secret={nyt_api_secret}"
#url_query
url_query = f"{url}api-key={nyt_api_key}&love={headline}&movies={section_name}&review={type_of_material}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}"

# %%
request = requests.get(url_query).json()
request

#response = requests.get(url_query)
#print(response.content)  # Print the response content to see if it's in JSON format
#data = response.json()  # Convert the response to JSON
#print(data)  # Print the JSON data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/05/31/us/politics/hunter-biden-bruen-justice-department.html',
#     'snippet': 'Hunter Biden’s legal team is invoking a Supreme Court decision his father has denounced as an affront to “common sense and the Constitution.”',
#     'source': 'The New York Times',
#     'headline': {'main': 'Hunter Biden’s Lawyers Cite Landmark Gun Ruling in Bid to Stave Off Charges',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Top Court’s Ruling on Guns May Void Biden Son’s Case',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'persons',
#       'value': 'Biden, Hunter',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Firearms', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Drug Abuse and Traffic',
# ...

# %%
#info = pd.read_html(url_query)
#info
list_of_articles = request["response"]["docs"]

list_of_articles
# Out:
# [{'web_url': 'https://www.nytimes.com/2023/05/31/us/politics/hunter-biden-bruen-justice-department.html',
#   'snippet': 'Hunter Biden’s legal team is invoking a Supreme Court decision his father has denounced as an affront to “common sense and the Constitution.”',
#   'source': 'The New York Times',
#   'headline': {'main': 'Hunter Biden’s Lawyers Cite Landmark Gun Ruling in Bid to Stave Off Charges',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Top Court’s Ruling on Guns May Void Biden Son’s Case',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'persons',
#     'value': 'Biden, Hunter',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'Firearms', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Drug Abuse and Traffic',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'United States Politics and Government',
#     'rank': 4,
#     'major': 'N'},
# ...

# %%
requests.get(url_query).json()
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/05/31/us/politics/hunter-biden-bruen-justice-department.html',
#     'snippet': 'Hunter Biden’s legal team is invoking a Supreme Court decision his father has denounced as an affront to “common sense and the Constitution.”',
#     'source': 'The New York Times',
#     'headline': {'main': 'Hunter Biden’s Lawyers Cite Landmark Gun Ruling in Bid to Stave Off Charges',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Top Court’s Ruling on Guns May Void Biden Son’s Case',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'persons',
#       'value': 'Biden, Hunter',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Firearms', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Drug Abuse and Traffic',
# ...

# %%
reviews_list = []
for page in range(20):
    full_url = f"{url}api-key={nyt_api_key}&q={filter_query}&sort={sort}&begin_date={begin_date}&end_date={end_date}&page={page}&fl={field_list}"
    try:
        reviews = requests.get(query_url).json()
        reviews_list.extend(reviews["response"]["docs"])
        print(f"Page {page} retrieved.")
        time.sleep(12)
    except:
        print(f"No results on page {page}.")
        break
# Out:
# Page 0 retrieved.
# Page 1 retrieved.
# Page 2 retrieved.
# Page 3 retrieved.
# Page 4 retrieved.
# Page 5 retrieved.
# Page 6 retrieved.
# Page 7 retrieved.
# Page 8 retrieved.
# Page 9 retrieved.
# Page 10 retrieved.
# Page 11 retrieved.
# Page 12 retrieved.
# Page 13 retrieved.
# Page 14 retrieved.
# Page 15 retrieved.
# Page 16 retrieved.
# Page 17 retrieved.
# Page 18 retrieved.
# Page 19 retrieved.

# %%
# Create an empty list to store the reviews
reviews_list = []

# Define the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?&=q"

# loop through pages 0-19
for page in range(20) :
    # create query with a page number
    full_url = f"{url}api-key={nyt_api_key}&q={filter_query}&sort={sort}&begin_date={begin_date}&end_date={end_date}&page={page}&fl={field_list}"
    # API results show 10 articles at a time
    #full_url = f"{url}q={headline}&page={0,1}&api-key={nyt_api_key}"
    #return 
    requests.get(full_url)

    
    # Make a "GET" request and retrieve the JSON
    retrieve_data = requests.get(full_url).json()

    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    if 'response' in retrieve_data and 'docs' in retrieve_data['response']:
        reviews_list.append(retrieve_data["response"]["docs"])
    else:
        print(f"No Reviews found on page {10}")
# Out:
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10
# No Reviews found on page 10

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(reviews_list, indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/27/opinion/africa-homosexuality-illegal.html",
#         "snippet": "Even in African countries that have decriminalized homosexuality, life is not easy for gay people.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "When Your Sexuality Is Against the Law",
#             "kicker": "Nicholas Kristof",
#             "content_kicker": null,
#             "print_headline": "When Your Sexuality Is a Crime",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "glocations",
#                 "value": "AFRICA",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "glocations",
#                 "value": "Sierra Leone",
#                 "rank": 2,
#                 "major": "N"
#             },
#             {
# ...

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
#df_reviewlists = pd.DataFrame(reviews_list)

#df_reviewlists= pd.DataFrame(reviews_list)

#df_reviewlists.head()

df_reviewlists = pd.json_normalize(reviews_list)
df_reviewlists.head()
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/27/opinion/afr...
# 1  https://www.nytimes.com/2023/05/27/opinion/pri...
# 2  https://www.nytimes.com/2023/05/27/us/america-...
# 3  https://www.nytimes.com/2023/05/27/arts/design...
# 4  https://www.nytimes.com/2023/05/27/arts/televi...
#
#                                              snippet              source  \
# 0  Even in African countries that have decriminal...  The New York Times
# 1  Prizes feel great. They also don’t change anyt...  The New York Times
# 2  We spoke to more than 100 people about the psy...  The New York Times
# 3  With a retrospective in Philadelphia, the arti...  The New York Times
# 4  The “Cruel Summer” actor explains why Frank Oc...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'glocations', 'value': 'AFRICA', 'ra...
# 1  [{'name': 'subject', 'value': 'Awards, Decorat...
# ...

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019.

df_reviewlists["title"] = df_reviewlists["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
df_reviewlists.head
# Out:
#                                              web_url  \
# 0  https://www.nytimes.com/2023/05/27/opinion/afr...
# 1  https://www.nytimes.com/2023/05/27/opinion/pri...
# 2  https://www.nytimes.com/2023/05/27/us/america-...
# 3  https://www.nytimes.com/2023/05/27/arts/design...
# 4  https://www.nytimes.com/2023/05/27/arts/televi...
#
#                                              snippet              source  \
# 0  Even in African countries that have decriminal...  The New York Times
# 1  Prizes feel great. They also don’t change anyt...  The New York Times
# 2  We spoke to more than 100 people about the psy...  The New York Times
# 3  With a retrospective in Philadelphia, the arti...  The New York Times
# 4  The “Cruel Summer” actor explains why Frank Oc...  The New York Times
#
#                                             keywords  \
# 0  [{'name': 'glocations', 'value': 'AFRICA', 'ra...
# 1  [{'name': 'subject', 'value': 'Awards, Decorat...
# ...

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
df_reviewlists["keywords"] = df_reviewlists["keywords"]/apply(extract_keywords)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[304], line 12
#       9     return extracted_keywords
#      11 # Fix the "keywords" column by converting cells from a list to a string
# ---> 12 df_reviewlists["keywords"] = df_reviewlists["keywords"]/apply(extract_keywords)
#
# NameError: name 'apply' is not defined

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
title = df_reviewlists["title"].to_list()
title
# Out:
# ['When Your Sexuality Is Against the La',
#  'I Won a Prize. So What',
#  'How Police Violence Weighs on Black American',
#  'The Pictures Are Miracles’: How Judith Joy Ross Finds Pain and Nobility in Portrait',
#  'BoJack Horseman',
#  'It’s a Trea',
#  'How Fighting for Conservative Causes Has Helped Ken Paxton Survive Legal Woe',
#  'Why TV Finales Matter (And Why They Are So Hard to Get Right',
#  'Mary Turner Pattiz, Rock D.J. During FM’s Heyday, Dies at 7',
#  'Love Letter: Not Part of the Pla',
#  'When Your Sexuality Is Against the La',
#  'I Won a Prize. So What',
#  'How Police Violence Weighs on Black American',
#  'The Pictures Are Miracles’: How Judith Joy Ross Finds Pain and Nobility in Portrait',
#  'BoJack Horseman',
#  'It’s a Trea',
#  'How Fighting for Conservative Causes Has Helped Ken Paxton Survive Legal Woe',
#  'Why TV Finales Matter (And Why They Are So Hard to Get Right',
#  'Mary Turner Pattiz, Rock D.J. During FM’s Heyday, Dies at 7',
# ...

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
url_tmdb = "https://api.themoviedb.org/3/search/movie?query="
#tmdb_key_string = "&api_key=" + tmdb_api_key

tmdb_key_string = f"{url_tmdb}&tmdb_api_key={tmdb_api_key}"

# %%
request = requests.get(tmdb_key_string)
request.status_code
# Out:
# 401

# %%
# Create an empty list to store the results
tmbd_movies_list = []


# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 50 == 0 



# Loop through the titles

    # Check if we need to sleep before making a request
if request_counter % 50 == 0 and request_counter != 0:
        time.sleep(10) 


    # Add 1 to the request counter
request_counter += 1
    
    # Perform a "GET" request for The Movie Database

movie_id = "get_movie_id"(title)



    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.

        # Get movie id


        # Make a request for a the full movie details
movie_details = "get_movie_details"(movie_id)

        # Execute "GET" request with url

retrieve_movies = requests.get(url_tmdb).json()

        
        # Extract the genre names into a list
genres = "extract_genres"(movie_details)
        # Extract the spoken_languages' English name into a list
spoken_languages = "extract_spoken_languages"(movie_details)
        # Extract the production_countries' name into a list
production_countries = "extract_production_countries"(movie_details)


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list
movie_data = {
        'title': title,
        'genres': genres,
        'spoken_languages': spoken_languages,
        'production_countries': production_countries
}
tmbd_movies_list.append(movie_data)

# Print out the title that was found
print(f"Movie found: {title}")
        # Print out the title that was found
# Out:
# <>:23: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:35: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:43: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:45: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:47: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:23: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:35: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:43: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:45: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# <>:47: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# /var/folders/yv/1k6t_v4x7798wpq87ddlnmjw0000gn/T/ipykernel_42135/818117724.py:23: SyntaxWarning: 'str' object is not callable; perhaps you missed a comma?
# ...

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(tmbd_movies_list, indent=4))
# Out:
# [
#     {
#         "title": "The Attachment Diaries",
#         "original_title": "El apego",
#         "budget": 0,
#         "genre": [
#             "Drama",
#             "Mystery",
#             "Thriller",
#             "Horror"
#         ],
#         "language": "es",
#         "spoken_languages": [
#             "Spanish"
#         ],
#         "homepage": "",
#         "overview": "Argentina, 1970s. A desperate young woman goes to a clinic to have a clandestine abortion. As her pregnancy is already through the fourth month, the doctor refuses. Instead, she proposes to sell the baby to one of her clients and offers to provide shelter in her house until the child is born. Their disturbed personalities will become intertwined in a strange and dangerous relationship.",
#         "popularity": 0.708,
#         "runtime": 102,
#         "revenue": 0,
#         "release_date": "2021-10-07",
#         "vote_average": 4.0,
#         "vote_count": 2,
# ...

# %%
# Convert the results to a DataFrame
df_tmbd_movies = pd.DataFrame(tmbd_movies_list)
df_tmbd_movies.head()
# Out:
#                          title             original_title    budget  \
# 0       The Attachment Diaries                   El apego         0
# 1         You Can Live Forever       You Can Live Forever         0
# 2    A Tourist's Guide to Love  A Tourist's Guide to Love         0
# 3      Other People's Children     Les Enfants des autres         0
# 4               One True Loves             One True Loves         0
# ..                         ...                        ...       ...
# 150              The Last Face              The Last Face         0
# 151              Lost in Paris            Paris pieds nus         0
# 152             The Other Half             The Other Half         0
# 153     The Ottoman Lieutenant     The Ottoman Lieutenant  40000000
# 154             Rich in Love 2            Ricos de Amor 2         0
#
#                                   genre language       spoken_languages  \
# 0    [Drama, Mystery, Thriller, Horror]       es              [Spanish]
# ...

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
df_merged = pd.merge(df_reviewlists, df_tmbd_movies, on="tittle", how="inner")
# Out:
#                               title                  original_title    budget  \
# 0            The Attachment Diaries                        El apego         0
# 1              You Can Live Forever            You Can Live Forever         0
# 2                    One True Loves                  One True Loves         0
# 3    The Lost Weekend: A Love Story  The Lost Weekend: A Love Story         0
# 4                A Thousand and One              A Thousand and One         0
# ..                              ...                             ...       ...
# 120            In Search of Fellini            In Search of Fellini         0
# 121                   The Last Face                   The Last Face         0
# 122                   Lost in Paris                 Paris pieds nus         0
# 123                  The Other Half                  The Other Half         0
# 124          The Ottoman Lieutenant          The Ottoman Lieutenant  40000000
#
# ...

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing



# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame
# Remove list brackets and quotation marks on the columns containing lists
columns_to_fix = ['column1', 'column2', 'column3']




# Create a list of characters to remove


characters_to_remove = ['[', ']', '\'']


# Loop through the list of columns to fix


for column in columns_to_fix:


    # Convert the column to type 'str'
    df_merged[column] = df_merged[column].astype(str)
    
    # Loop through characters to remove
    for char in characters_to_remove:
        df_merged[column] = df_merged[column].str.replace(char, '')

# Display the fixed DataFrame
df_merged.head()
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# ...

# %%
# Drop "byline.person" column
df_merged.drop(columns=["byline.person"], inplace=True)

# %%
# Delete duplicate rows and reset index
df_merged.drop_duplicates(inplace=True)
# Out:
#                             title                  original_title  budget  \
# 0          The Attachment Diaries                        El apego       0
# 1            You Can Live Forever            You Can Live Forever       0
# 2                  One True Loves                  One True Loves       0
# 3  The Lost Weekend: A Love Story  The Lost Weekend: A Love Story       0
# 4              A Thousand and One              A Thousand and One       0
#
#                               genre language spoken_languages  \
# 0  Drama, Mystery, Thriller, Horror       es          Spanish
# 1                    Drama, Romance       en  French, English
# 2            Romance, Drama, Comedy       en          English
# 3                       Documentary       en
# 4                             Drama       en          English
#
#                                             homepage  \
# 0
# 1  https://gooddeedentertainment.com/you-can-live...
# 2
# 3
# ...

# %%
# Export data to CSV without the index
df_merged.to_csv("output_data/nyt_movies_reviews.csv", index = False)
